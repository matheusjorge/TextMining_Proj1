# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import os
import string
import nltk
import re
from nltk.stem.snowball import SnowballStemmer
import pandas as pd

# %%
files = [open("cbr-ilp-ir/"+f, 'r', encoding='ISO-8859-14').read() for f in sorted(os.listdir('cbr-ilp-ir/'))]

# %%
def token_stem(text):
    # Criando tokens
    tokens = [w for w in nltk.wordpunct_tokenize(text)]
    filtered_tokens = []
    # Lematizador utilizado
    stemmer = SnowballStemmer("english")
    # Deixando somente termos que contém letras
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    # Lematização dos tokens selecionados
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return set(stems)
    
#print(files[0])
token_stem(files[0])
# Out:
# {'29a',
#  '4th',
#  'a',
#  'aamodt',
#  'abaoub',
#  'abstract',
#  'acad',
#  'academ',
#  'academi',
#  'acm',
#  'agr',
#  'aimsa',
#  'algorithm',
#  'along',
#  'ami',
#  'an',
#  'anaheim',
#  'analysi',
#  'and',
#  'approach',
#  'are',
#  'artifici',
#  'as',
#  'attent',
#  'b',
#  'barsalou',
#  'base',
#  'behavior',
#  'bench',
#  'bergadano',
#  'between',
#  'bg',
#  'biberman',
#  'block',
#  'bonchev',
#  'both',
#  'bulgaria',
#  'bulgarian',
#  'by',
#  'c',
#  'ca',
#  'cabelli',
#  'capabl',
#  'capon',
#  'case',
#  'categori',
#  'cbr',
#  'coenen',
#  'communic',
#  'compon',
#  'concept',
#  'conceptu',
#  'confer',
#  'conflict',
#  'congress',
#  'contex',
#  'corcas',
#  'correct',
#  'cost',
#  'cours',
#  'cybernet',
#  'd',
#  'dahou',
#  'data',
#  'de',
#  'deal',
#  'deduct',
#  'depend',
#  'descript',
#  'design',
#  'diagnosi',
#  'dissert',
#  'domain',
#  'ecml',
#  'ed',
#  'edward',
#  'electromyographi',
#  'email',
#  'engin',
#  'exist',
#  'experi',
#  'experiment',
#  'explan',
#  'extend',
#  'f',
#  'featur',
#  'ferri',
#  'first',
#  'flexibl',
#  'for',
#  'form',
#  'frame',
#  'from',
#  'fundament',
#  'g',
#  'general',
#  'gennadi',
#  'gh',
#  'giacometti',
#  'gold',
#  'hale',
#  'hammond',
#  'hampton',
#  'harper',
#  'hybrid',
#  'i',
#  'idea',
#  'iinf',
#  'illustr',
#  'improv',
#  'in',
#  'induct',
#  'infer',
#  'inform',
#  'instanc',
#  'institut',
#  'int',
#  'integr',
#  'intellig',
#  'intens',
#  'iordanova',
#  'irvin',
#  'is',
#  'it',
#  'ixth',
#  'j',
#  'jerusalem',
#  'jorrand',
#  'june',
#  'k',
#  'kaufmann',
#  'kbs',
#  'kedar',
#  'keller',
#  'knowledg',
#  'kodratoff',
#  'kolodn',
#  'l',
#  'learn',
#  'list',
#  'lnaj',
#  'm',
#  'machin',
#  'main',
#  'mainten',
#  'markov',
#  'match',
#  'mateo',
#  'matwin',
#  'measur',
#  'mechelen',
#  'memori',
#  'method',
#  'michaiski',
#  'michalsi',
#  'michalski',
#  'mit',
#  'mitchel',
#  'ml02',
#  'modul',
#  'morgan',
#  'multistrategi',
#  'nation',
#  'nearest',
#  'neighbor',
#  'newli',
#  'ninth',
#  'of',
#  'on',
#  'oper',
#  'p',
#  'paid',
#  'paper',
#  'part',
#  'pattern',
#  'ph',
#  'plan',
#  'plant',
#  'point',
#  'poseidon',
#  'press',
#  'privat',
#  'problem',
#  'proc',
#  'procedur',
#  'proceed',
#  'produc',
#  'propos',
#  'pubi',
#  'r',
#  'raedt',
#  'rbr',
#  'real',
#  'reason',
#  'reconcil',
#  'recurs',
#  'refer',
#  'reflect',
#  'represent',
#  'result',
#  'revis',
#  'reymond',
#  'riall',
#  'robot',
#  'rosenbloom',
#  'rule',
#  's',
#  'salzberg',
#  'san',
#  'scienc',
#  'scientif',
#  'search',
#  'second',
#  'select',
#  'sgurev',
#  'shade',
#  'similar',
#  'singapor',
#  'sleeman',
#  'sofia',
#  'solut',
#  'solv',
#  'solver',
#  'some',
#  'special',
#  'springer',
#  'st',
#  'stanfil',
#  'strong',
#  'subsymbol',
#  'sustain',
#  'symbol',
#  'system',
#  't',
#  'task',
#  'techniqu',
#  'technolog',
#  'tecuci',
#  'the',
#  'theoret',
#  'theori',
#  'theun',
#  'this',
#  'through',
#  'tier',
#  'to',
#  'tool',
#  'toward',
#  'tradit',
#  'treat',
#  'trondheim',
#  'two',
#  'typic',
#  'uc',
#  'unifi',
#  'univers',
#  'use',
#  'v',
#  'van',
#  'verlag',
#  'view',
#  'vila',
#  'vith',
#  'waltz',
#  'weight',
#  'which',
#  'while',
#  'with',
#  'workshop',
#  'world',
#  'y',
#  'z',
#  'zhang'}

# %%
v = TfidfVectorizer(lowercase=True,min_df=0.1,max_df=0.9, tokenizer=token_stem, stop_words=nltk.)
v.encoding = 'ISO-8859-14'
m = v.fit_transform(files)
print(m.toarray().shape)
v.get_params()
v.get_feature_names()
# Out:
# (574, 480)
# ['2nd',
#  '3rd',
#  '4th',
#  '5th',
#  'aaai',
#  'aamodt',
#  'about',
#  'ac',
#  'academ',
#  'access',
#  'acm',
#  'acquisit',
#  'activ',
#  'adapt',
#  'addison',
#  'advanc',
#  'aha',
#  'ai',
#  'aid',
#  'al',
#  'algorithm',
#  'all',
#  'allow',
#  'also',
#  'althoff',
#  'american',
#  'an',
#  'analog',
#  'analysi',
#  'annual',
#  'appear',
#  'appli',
#  'applic',
#  'approach',
#  'approxim',
#  'architectur',
#  'are',
#  'artifici',
#  'as',
#  'assess',
#  'associ',
#  'at',
#  'august',
#  'autom',
#  'automat',
#  'avail',
#  'b',
#  'base',
#  'be',
#  'been',
#  'bergmann',
#  'berlin',
#  'between',
#  'boston',
#  'both',
#  'bound',
#  'build',
#  'but',
#  'by',
#  'c',
#  'ca',
#  'california',
#  'call',
#  'cambridg',
#  'can',
#  'case',
#  'cbr',
#  'center',
#  'chang',
#  'class',
#  'classif',
#  'classifi',
#  'claus',
#  'cluster',
#  'cognit',
#  'collect',
#  'colleg',
#  'com',
#  'combin',
#  'communic',
#  'compar',
#  'comparison',
#  'complet',
#  'complex',
#  'compon',
#  'comput',
#  'concept',
#  'conceptu',
#  'conf',
#  'confer',
#  'consid',
#  'consist',
#  'constraint',
#  'construct',
#  'content',
#  'context',
#  'control',
#  'cost',
#  'cs',
#  'cunningham',
#  'current',
#  'data',
#  'databas',
#  'david',
#  'de',
#  'decis',
#  'defin',
#  'definit',
#  'demonstr',
#  'depart',
#  'depend',
#  'dept',
#  'deriv',
#  'describ',
#  'descript',
#  'design',
#  'determin',
#  'develop',
#  'differ',
#  'digit',
#  'direct',
#  'discoveri',
#  'discuss',
#  'distribut',
#  'document',
#  'domain',
#  'dynam',
#  'dzeroski',
#  'e',
#  'each',
#  'ed',
#  'edit',
#  'editor',
#  'edu',
#  'effect',
#  'effici',
#  'empir',
#  'engin',
#  'entail',
#  'environ',
#  'erlbaum',
#  'estim',
#  'et',
#  'european',
#  'evalu',
#  'ewcbr',
#  'exampl',
#  'exist',
#  'experi',
#  'experiment',
#  'expert',
#  'explan',
#  'explor',
#  'extend',
#  'extract',
#  'f',
#  'featur',
#  'fifth',
#  'find',
#  'first',
#  'formal',
#  'foundat',
#  'fourth',
#  'framework',
#  'franc',
#  'from',
#  'function',
#  'futur',
#  'g',
#  'general',
#  'generat',
#  'germani',
#  'given',
#  'goal',
#  'group',
#  'guid',
#  'h',
#  'hall',
#  'hammond',
#  'has',
#  'have',
#  'heurist',
#  'hierarch',
#  'high',
#  'hill',
#  'how',
#  'howev',
#  'html',
#  'http',
#  'human',
#  'hybrid',
#  'i',
#  'iccbr',
#  'ieee',
#  'ijcai',
#  'ilp',
#  'implement',
#  'import',
#  'improv',
#  'inc',
#  'increment',
#  'index',
#  'induct',
#  'infer',
#  'inform',
#  'ing',
#  'instanc',
#  'institut',
#  'int',
#  'integr',
#  'intellig',
#  'interact',
#  'intern',
#  'interpret',
#  'into',
#  'introduc',
#  'introduct',
#  'invers',
#  'investig',
#  'is',
#  'issu',
#  'it',
#  'itali',
#  'john',
#  'joint',
#  'journal',
#  'juli',
#  'june',
#  'k',
#  'kaufmann',
#  'kean',
#  'kluwer',
#  'knowledg',
#  'kolodn',
#  'l',
#  'laboratori',
#  'languag',
#  'larg',
#  'lawrenc',
#  'leak',
#  'learn',
#  'lectur',
#  'level',
#  'librari',
#  'limit',
#  'line',
#  'linguist',
#  'lnai',
#  'logic',
#  'london',
#  'los',
#  'ma',
#  'machin',
#  'magazin',
#  'mail',
#  'make',
#  'manag',
#  'mani',
#  'massachusett',
#  'match',
#  'mateo',
#  'mathemat',
#  'may',
#  'measur',
#  'mechan',
#  'meet',
#  'memori',
#  'method',
#  'methodolog',
#  'metric',
#  'mine',
#  'mit',
#  'mitchel',
#  'model',
#  'more',
#  'morgan',
#  'most',
#  'muggleton',
#  'multi',
#  'multipl',
#  'n',
#  'nation',
#  'natur',
#  'need',
#  'network',
#  'neural',
#  'new',
#  'nj',
#  'no',
#  'non',
#  'not',
#  'note',
#  'number',
#  'o',
#  'object',
#  'one',
#  'onli',
#  'oper',
#  'optim',
#  'or',
#  'order',
#  'organ',
#  'other',
#  'our',
#  'over',
#  'p',
#  'page',
#  'paper',
#  'parallel',
#  'park',
#  'part',
#  'particular',
#  'pattern',
#  'perform',
#  'ph',
#  'phd',
#  'plan',
#  'plaza',
#  'possibl',
#  'pp',
#  'practic',
#  'predict',
#  'present',
#  'press',
#  'previous',
#  'principl',
#  'probabilist',
#  'problem',
#  'proc',
#  'proceed',
#  'process',
#  'progol',
#  'program',
#  'project',
#  'propos',
#  'provid',
#  'publish',
#  'qualiti',
#  'queri',
#  'question',
#  'quinlan',
#  'r',
#  'raedt',
#  'real',
#  'reason',
#  'recognit',
#  'refin',
#  'relat',
#  'relev',
#  'report',
#  'repres',
#  'represent',
#  'requir',
#  'research',
#  'result',
#  'retriev',
#  'reus',
#  'review',
#  'role',
#  'rule',
#  's',
#  'san',
#  'scale',
#  'school',
#  'scienc',
#  'search',
#  'second',
#  'select',
#  'semant',
#  'septemb',
#  'seri',
#  'set',
#  'show',
#  'sigir',
#  'signific',
#  'similar',
#  'simpl',
#  'smith',
#  'smyth',
#  'so',
#  'societi',
#  'softwar',
#  'solut',
#  'solv',
#  'some',
#  'son',
#  'space',
#  'special',
#  'specif',
#  'springer',
#  'standard',
#  'state',
#  'statist',
#  'strategi',
#  'structur',
#  'studi',
#  'such',
#  'support',
#  'symbol',
#  'symposium',
#  'system',
#  't',
#  'task',
#  'technic',
#  'techniqu',
#  'technolog',
#  'term',
#  'test',
#  'text',
#  'than',
#  'that',
#  'their',
#  'then',
#  'theoret',
#  'theori',
#  'these',
#  'thesi',
#  'they',
#  'third',
#  'this',
#  'three',
#  'through',
#  'time',
#  'tion',
#  'tool',
#  'topic',
#  'toward',
#  'tr',
#  'train',
#  'transact',
#  'transform',
#  'tree',
#  'two',
#  'type',
#  'u',
#  'uk',
#  'under',
#  'understand',
#  'unifi',
#  'univers',
#  'up',
#  'usa',
#  'use',
#  'user',
#  'v',
#  'valu',
#  'van',
#  'veloso',
#  'veri',
#  'verlag',
#  'version',
#  'via',
#  'view',
#  'vol',
#  'volum',
#  'w',
#  'was',
#  'way',
#  'we',
#  'web',
#  'weight',
#  'well',
#  'wesley',
#  'wess',
#  'when',
#  'where',
#  'which',
#  'wide',
#  'wiley',
#  'will',
#  'with',
#  'within',
#  'word',
#  'work',
#  'workshop',
#  'world',
#  'www',
#  'y',
#  'york',
#  'z']

# %%
m
# Out:
# <574x480 sparse matrix of type '<class 'numpy.float64'>'
# 	with 69698 stored elements in Compressed Sparse Row format>

# %%
data = pd.DataFrame(data=m.toarray(), columns=v.get_feature_names())
data
# Out:
#           2nd       3rd       4th       5th      aaai    aamodt     about  \
# 0    0.000000  0.000000  0.117094  0.000000  0.000000  0.114126  0.000000
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.000000  0.000000  0.000000  0.000000  0.076942  0.000000  0.000000
# 3    0.000000  0.000000  0.000000  0.000000  0.076786  0.000000  0.108066
# 4    0.000000  0.000000  0.000000  0.000000  0.071156  0.103433  0.000000
# 5    0.000000  0.000000  0.000000  0.000000  0.000000  0.126207  0.122191
# 6    0.000000  0.000000  0.000000  0.000000  0.000000  0.108969  0.105502
# 7    0.000000  0.000000  0.000000  0.127952  0.083500  0.121377  0.000000
# 8    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9    0.000000  0.000000  0.000000  0.000000  0.072779  0.000000  0.000000
# 10   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.125787
# 11   0.000000  0.000000  0.000000  0.000000  0.089985  0.000000  0.126641
# 12   0.000000  0.000000  0.000000  0.000000  0.096762  0.000000  0.000000
# 13   0.000000  0.000000  0.000000  0.000000  0.070845  0.000000  0.000000
# 14   0.000000  0.000000  0.000000  0.000000  0.088534  0.000000  0.124599
# 15   0.000000  0.221852  0.000000  0.000000  0.000000  0.000000  0.000000
# 16   0.000000  0.000000  0.000000  0.000000  0.084309  0.000000  0.000000
# 17   0.000000  0.000000  0.000000  0.000000  0.079035  0.000000  0.000000
# 18   0.000000  0.000000  0.000000  0.000000  0.000000  0.093592  0.000000
# 19   0.000000  0.000000  0.000000  0.000000  0.099563  0.000000  0.000000
# 20   0.000000  0.000000  0.000000  0.000000  0.083561  0.000000  0.000000
# 21   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 
0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 24   0.000000  0.000000  0.000000    ...     0.055914  0.000000  0.000000
# 25   0.095132  0.000000  0.000000    ...     0.044980  0.000000  0.000000
# 26   0.000000  0.087623  0.120811    ...     0.000000  0.000000  0.000000
# 27   0.000000  0.072488  0.000000    ...     0.039751  0.000000  0.000000
# 28   0.000000  0.000000  0.000000    ...     0.055294  0.140305  0.000000
# 29   0.000000  0.000000  0.000000    ...     0.046280  0.000000  0.000000
# ..        ...       ...       ...    ...          ...       ...       ...
# 544  0.100502  0.000000  0.000000    ...     0.047519  0.000000  0.000000
# 545  0.000000  0.000000  0.000000    ...     0.057805  0.000000  0.000000
# 546  0.000000  0.000000  0.144022    ...     0.057283  0.145353  0.000000
# 547  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 548  0.113872  0.000000  0.000000    ...     0.053840  0.000000  0.000000
# 549  0.000000  0.000000  0.000000    ...     0.056256  0.000000  0.149141
# 550  0.000000  0.000000  0.000000    ...     0.050314  0.000000  0.000000
# 551  0.071746  0.061859  0.085288    ...     0.033922  0.000000  0.089932
# 552  0.000000  0.000000  0.102337    ...     0.040703  0.000000  0.107909
# 553  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.186042
# 554  0.000000  0.000000  0.000000    ...     0.052513  0.000000  0.139217
# 555  0.104063  0.089723  0.000000    ...     0.000000  0.000000  0.000000
# 556  0.106184  0.000000  0.000000    ...     0.050205  0.000000  0.133100
# 557  0.000000  0.000000  0.000000    ...     0.052225  0.000000  0.138454
# 558  0.000000  0.000000  0.108526    ...     0.000000  0.000000  0.000000
# 559  0.000000  0.066522  0.091717    ...     0.036479  0.000000  0.096711
# 560  0.000000  0.060376  0.000000    ...     0.033109  0.000000  0.087776
# 561  0.112842  0.000000  0.134141    ...     0.000000  0.000000  0.000000
# 562  0.000000  0.000000  0.000000    ...     0.054318  0.000000  0.000000
# 563  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.116906
# 564  0.000000  0.000000  0.000000    ...     0.058345  0.000000  0.000000
# 565  0.000000  0.000000  0.128197    ...     0.050989  0.000000  0.000000
# 566  0.000000  0.000000  0.188136    ...     0.074829  0.000000  0.000000
# 567  0.000000  0.000000  0.000000    ...     0.047903  0.000000  0.126996
# 568  0.000000  0.057718  0.079579    ...     0.031652  0.080314  0.000000
# 569  0.000000  0.000000  0.116080    ...     0.000000  0.117152  0.000000
# 570  0.000000  0.097078  0.133846    ...     0.053236  0.000000  0.000000
# 571  0.000000  0.000000  0.000000    ...     0.053601  0.000000  0.000000
# 572  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 573  0.102665  0.000000  0.122043    ...     0.048541  0.000000  0.000000
#
#          work  workshop     world       www         y      york         z
# 0    0.000000  0.053625  0.099620  0.000000  0.084205  0.000000  0.120872
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.000000  0.000000  0.000000  0.000000  0.082521  0.000000  0.000000
# 3    0.084559  0.000000  0.000000  0.000000  0.000000  0.086661  0.000000
# 4    0.000000  0.048601  0.000000  0.000000  0.000000  0.000000  0.000000
# 5    0.000000  0.059301  0.110165  0.000000  0.000000  0.000000  0.000000
# 6    0.000000  0.051202  0.095118  0.000000  0.000000  0.084605  0.000000
# 7    0.091953  0.057032  0.000000  0.000000  0.089554  0.000000  0.000000
# 8    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 